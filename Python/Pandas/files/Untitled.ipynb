# %%
import pandas
data = pandas.read_csv("supermarkets.csv")

import os
os.listdir()

from matplotlib import pyplot as plot

# %%
csvdata = pandas.read_csv("supermarkets.csv")
csvdata
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
jsondata = pandas.read_json("supermarkets.json")
jsondata
plot.title("shops in USA against employees")
plot.xlabel("shop names")
plot.ylabel("no of Employees")
plot.plot(jsondata.Name, jsondata.Employees)
plot.show
plot?

# %%
exceldata = pandas.read_excel("supermarkets.xlsx", sheet_name = 0)
exceldata
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
txtdata = pandas.read_csv("supermarkets-commas.txt")
txtdata
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
txt2data = pandas.read_csv("supermarkets-semi-colons.txt")
txtdata
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
print("this uses one row as column names")
txt3data = pandas.read_csv("supermarkets-workers.txt")
txt3data
# Out:
# this uses one row as column names
#    1  Peacemaker    Otoo  27    Ghana  Mumford
# 0  2       Agnes  Donkoh  22  Nigeria    Lagos
# 1  3     Francis  Tawiah  25    Ghana   Kumasi
# 2  4  Peacemaker    Otoo  27    Ghana  Mumford
# 3  5       Agnes  Donkoh  22  Nigeria    Lagos
# 4  6     Francis  Tawiah  25    Ghana   Kumasi

# %%
txt4data = pandas.read_csv("supermarkets-workers.txt", header = None)
txt4data
# Out:
#    0           1       2   3        4        5
# 0  1  Peacemaker    Otoo  27    Ghana  Mumford
# 1  2       Agnes  Donkoh  22  Nigeria    Lagos
# 2  3     Francis  Tawiah  25    Ghana   Kumasi
# 3  4  Peacemaker    Otoo  27    Ghana  Mumford
# 4  5       Agnes  Donkoh  22  Nigeria    Lagos
# 5  6     Francis  Tawiah  25    Ghana   Kumasi

# %% [markdown]
# ### setting the column names

# %%
txt4data.columns=["id","firstname","Surname","age","country","region"]
txt4data
# Out:
#    id   firstname Surname  age  country   region
# 0   1  Peacemaker    Otoo   27    Ghana  Mumford
# 1   2       Agnes  Donkoh   22  Nigeria    Lagos
# 2   3     Francis  Tawiah   25    Ghana   Kumasi
# 3   4  Peacemaker    Otoo   27    Ghana  Mumford
# 4   5       Agnes  Donkoh   22  Nigeria    Lagos
# 5   6     Francis  Tawiah   25    Ghana   Kumasi

# %% [markdown]
# ### setting the rows name

# %%
txt5data = txt4data.set_index("id")
txt5data
# Out:
#      firstname Surname  age  country   region
# id
# 1   Peacemaker    Otoo   27    Ghana  Mumford
# 2        Agnes  Donkoh   22  Nigeria    Lagos
# 3      Francis  Tawiah   25    Ghana   Kumasi
# 4   Peacemaker    Otoo   27    Ghana  Mumford
# 5        Agnes  Donkoh   22  Nigeria    Lagos
# 6      Francis  Tawiah   25    Ghana   Kumasi

# %%
plot.plot(txt5data.country,txt5data.age)
plot.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
